# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import Perceptron
import seaborn as sns
import numpy as np

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['input1']=[1,1,0,0]
or_data['input2']=[1,0,1,0]
or_data['ouput']=[1,1,1,0]

# %%
and_data['input1']=[1,1,0,0]
and_data['input2']=[1,0,1,0]
and_data['ouput']=[1,0,0,0]

# %%
xor_data['input1']=[1,1,0,0]
xor_data['input2']=[1,0,1,0]
xor_data['ouput']=[0,1,1,0]

# %%
xor_data
# Out:
#    input1  input2  ouput
# 0       1       1      0
# 1       1       0      1
# 2       0       1      1
# 3       0       0      0

# %%
plt.scatter(x=xor_data['input1'],y=xor_data['input2'],c=xor_data['ouput'])

# %%
plt.scatter(x=and_data['input1'],y=and_data['input2'],c=and_data['ouput'])

# %%
plt.scatter(x=or_data['input1'],y=or_data['input2'],c=or_data['ouput'])

# %%
Or=Perceptron()
And=Perceptron()
Xor=Perceptron()

# %%
Or.fit(or_data.iloc[:,:-1],or_data['ouput'])
# Out:
# Perceptron()

# %%
print(Or.intercept_)
print(Or.coef_)
# Out:
# [-1.]
# [[2. 2.]]

# %%
And.fit(and_data.iloc[:,:-1],and_data['ouput'])
# Out:
# Perceptron()

# %%
print(And.intercept_)
print(And.coef_)
# Out:
# [-2.]
# [[2. 2.]]

# %%
Xor.fit(xor_data.iloc[:,:-1],xor_data['ouput'])
# Out:
# Perceptron()

# %%
print(Xor.intercept_)
print(Xor.coef_)
# Out:
# [0.]
# [[0. 0.]]

# %%
x=np.linspace(-1,1,5)
y=-x+1

# %%
plt.plot(x,y)
sns.scatterplot(x=and_data['input1'],y=and_data['input2'],hue=and_data['ouput'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
x1=np.linspace(-1,1,5)
y1=-x+0.5

# %%
plt.plot(x1, y1)

sns.scatterplot(x=or_data['input1'], y=or_data['input2'], hue=or_data['ouput'], s=200)

plt.show()

# %%
from mlxtend.plotting import plot_decision_regions

# Ab aapka code chal jayega
plot_decision_regions(xor_data.iloc[:,0:2].values, xor_data.iloc[:,-1].values, clf=Xor, legend=2)
plt.xlabel('Input 1')
plt.ylabel('Input 2')
plt.title('Perceptron XOR Decision Region')
plt.show()
# Out:
# C:\Users\rm948\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
